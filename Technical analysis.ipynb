# %%
import quandl
import pandas as pd
import math as m
import matplotlib.pyplot as plt
fig = plt.figure()
fig.set_size_inches(10,3)
# %matplotlib inline

# %%
nse_nifty = quandl.get("NSE/CNX_NIFTY", start_date='2012-01-01', end_date='2017-06-23', api_key='ifmqBTqyPy8nVfJxtPuN')

# %%
nse_nifty
# Out:
#                Open     High      Low    Close  Shares Traded  \
# Date
# 2012-01-02  4640.20  4645.95  4588.05  4636.75    108460668.0
# 2012-01-03  4675.80  4773.10  4675.80  4765.30    146621115.0
# 2012-01-04  4774.95  4782.85  4728.85  4749.65    165938849.0
# 2012-01-05  4749.00  4779.80  4730.15  4749.95    177862936.0
# 2012-01-06  4724.15  4794.90  4686.85  4754.10    176057282.0
# 2012-01-07  4755.60  4759.40  4743.05  4746.90     18783880.0
# 2012-01-09  4747.55  4758.70  4695.45  4742.80    147534537.0
# 2012-01-10  4771.85  4855.90  4768.25  4849.55    201661174.0
# 2012-01-11  4863.15  4877.20  4841.60  4860.95    209079758.0
# 2012-01-12  4840.95  4869.20  4803.90  4831.25    183068697.0
# 2012-01-13  4861.95  4898.85  4834.20  4866.00    230940604.0
# 2012-01-16  4844.00  4880.80  4827.05  4873.90    160479891.0
# 2012-01-17  4904.50  4975.55  4904.00  4967.30    223004183.0
# 2012-01-18  4977.75  4980.65  4931.05  4955.80    211198796.0
# ...

# %%
nse_nifty.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Shares Traded', 'Turnover (Rs. Cr)'], dtype='object')

# %%
fig = plt.figure()
fig.set_size_inches(25,10)
nse_nifty['Close'].fillna(0).pct_change().plot()
plt.title(u"Nifty stock daily returns", weight='bold');

# %%
nse_nifty['Close'].max()
# Out:
# 9675.1000000000004

# %%
nifty_50= ["ACC", "ADANIPORTS", "AMBUJACEM", "ASIANPAINT", "AXISBANK", "BANKBARODA", "BPCL", "BHARTIARTL", "BOSCHLTD", "AUROPHARMA", "CIPLA", "COALINDIA", "DRREDDY", "GAIL", "GRASIM", "HCLTECH", "HDFCBANK", "HEROMOTOCO", "HINDALCO", "HINDUNILVR", "HDFC", "ITC", "IOC", "IBULHSGFIN", "ICICIBANK", "INDUSINDBK", "INFY", "KOTAKBANK", "LT", "LUPIN", "MARUTI", "NTPC", "ONGC", "POWERGRID", "INFRATEL", "RELIANCE", "SBIN", "SUNPHARMA", "TCS", "TATAMOTORS", "TATAPOWER", "TATASTEEL", "TECHM", "ULTRACEMCO", "EICHERMOT", "WIPRO", "YESBANK", "ZEEL", "TATAMTRDVR"]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(50,20)
nse_nifty['Close'].pct_change(21).fillna(0).plot(legend=True)
for stock in nifty_50:
    try:
        stock_name = "NSE/" + stock
        print(stock_name)
        stock_data = quandl.get(stock_name, start_date='2012-01-01', end_date='2017-06-19', api_key='ifmqBTqyPy8nVfJxtPuN')
        stock_data['Close'].pct_change(21).fillna(0).plot(secondary_y=True, style='g',legend=True)
    except NotFoundError:
        print("Not found" + stock_name)
        pass
    except LimitExceededError:
        print("need to wait because of limit exceeded...")
plt.title(u"Nifty stocks", weight='bold');
# Out:
# NSE/ACC
# NSE/ADANIPORTS
# NSE/AMBUJACEM
# NSE/ASIANPAINT
# NSE/AXISBANK
# NSE/BANKBARODA
# NSE/BPCL
# NSE/BHARTIARTL
# NSE/BOSCHLTD
# NSE/AUROPHARMA
# NSE/CIPLA
# NSE/COALINDIA
# NSE/DRREDDY
# NSE/GAIL
# NSE/GRASIM
# NSE/HCLTECH
# NSE/HDFCBANK
# NSE/HEROMOTOCO
# NSE/HINDALCO
# NSE/HINDUNILVR
# NSE/HDFC
# NSE/ITC
# NSE/IOC
# NSE/IBULHSGFIN
# NSE/ICICIBANK
# NSE/INDUSINDBK
# NSE/INFY
# NSE/KOTAKBANK
# NSE/LT
# NSE/LUPIN
# NSE/MARUTI
# NSE/NTPC
# NSE/ONGC
# NSE/POWERGRID
# NSE/INFRATEL
# NSE/RELIANCE
# NSE/SBIN
# NSE/SUNPHARMA
# NSE/TCS
# NSE/TATAMOTORS
# NSE/TATAPOWER
# NSE/TATASTEEL
# NSE/TECHM
# NSE/ULTRACEMCO
# NSE/EICHERMOT
# NSE/WIPRO
# NSE/YESBANK
# NSE/ZEEL
# NSE/TATAMTRDVR

# %%
from datetime import datetime
import backtrader as bt

class SmaCross(bt.SignalStrategy):
    def __init__(self):
        sma8, sma20, sma50 = bt.ind.SMA(period=8), bt.ind.SMA(period=20), bt.ind.SMA(period=50)
        #short_term_crossover = bt.ind.CrossOver(sma8, sma20)
        long_term_crossover = bt.ind.CrossOver(sma8, sma20)
        self.signal_add(bt.SIGNAL_LONG, long_term_crossover)

cerebro = bt.Cerebro()
cerebro.addstrategy(SmaCross)

data0 = bt.feeds.YahooFinanceData(dataname='AAPL', fromdate=datetime(2016, 1, 1),
                                  todate=datetime(2017, 6, 23))
cerebro.adddata(data0)

cerebro.run()
cerebro.plot()
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# [[<matplotlib.figure.Figure at 0x11372c748>]]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(50,20)

# %%
dir(cerebro)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_timer',
#  '_broker',
#  '_brokernotify',
#  '_check_timers',
#  '_dataid',
#  '_datanotify',
#  '_dolive',
#  '_dooptimize',
#  '_dopreload',
#  '_doreplay',
#  '_dorunonce',
#  '_event_stop',
#  '_exactbars',
#  '_init_stcount',
#  '_next_stid',
#  '_next_writers',
#  '_notify_data',
#  '_notify_store',
#  '_pretimers',
#  '_runnext',
#  '_runnext_old',
#  '_runonce',
#  '_runonce_old',
#  '_signal_accumulate',
#  '_signal_concurrent',
#  '_signal_strat',
#  '_storenotify',
#  '_timers',
#  '_timerscheat',
#  '_tradingcal',
# ...

# %%
cerebro.result
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-0f011fa7bcbf> in <module>()
# ----> 1 cerebro.result
#
# AttributeError: 'Cerebro' object has no attribute 'result'
